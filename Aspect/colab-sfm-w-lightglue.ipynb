# %%
# !git clone --quiet --recursive https://github.com/cvg/Hierarchical-Localization/
# %cd Hierarchical-Localization
# !pip install --progress-bar off --quiet -e .
# !pip install --progress-bar off --quiet --upgrade plotly
# %cd ..
# !git clone https://github.com/SeanAndrie/SfM-with-LightGlue-Streamlit.git
# !pip install -r "/content/SfM-with-LightGlue-Streamlit/Aspect/requirements.txt"
# !pip install pyngrok
# Out:
# /content/Hierarchical-Localization
#   Preparing metadata (setup.py) ... done
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
# /content
# Cloning into 'SfM-with-LightGlue-Streamlit'...
# remote: Enumerating objects: 108, done.
# remote: Counting objects: 100% (108/108), done.
# remote: Compressing objects: 100% (102/102), done.
# remote: Total 108 (delta 8), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (108/108), 5.29 MiB | 18.48 MiB/s, done.
# Resolving deltas: 100% (8/8), done.
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.3/126.3 kB 1.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 17.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.2/62.2 MB 8.9 MB/s eta 0:00:00
# ...

# %%
# !pip install streamlit -q
# !pip install timm
# Out:
# ...
#   Using cached timm-1.0.3-py3-none-any.whl (2.3 MB)
# ...

# %%
# from pyngrok import ngrok

# ngrok.set_auth_token('2glThH6N5rRYuMpUyWeD1Iw41JY_62yMwbTgYuMTB6EjrntgR')
# public_url = ngrok.connect(addr = '8501', proto = 'http')
# print(f'Your Streamlit App is Live at {public_url}')
# Out:
# Your Streamlit App is Live at NgrokTunnel: "https://67f1-34-170-112-125.ngrok-free.app" -> "http://localhost:8501"

# %%
# !streamlit run /content/SfM-with-LightGlue-Streamlit/Aspect/main.py & npx localtunnel --port 8501
# Out:
# ...
#
#
#   You can now view your Streamlit app in your browser.
#
#   Network URL: http://172.28.0.12:8501
#   External URL: http://34.170.112.125:8501
#
# npx: installed 22 in 2.131s
# your url is: https://upset-cobras-burn.loca.lt
# 2024-05-21 06:25:16.773 Uncaught app exception
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/streamlit/runtime/scriptrunner/script_runner.py", line 600, in _run_script
#     exec(code, module.__dict__)
#   File "/content/SfM-with-LightGlue-Streamlit/Aspect/main.py", line 271, in <module>
#     main()
#   File "/content/SfM-with-LightGlue-Streamlit/Aspect/main.py", line 268, in main
#     SfMPage.render()
#   File "/content/SfM-with-LightGlue-Streamlit/Aspect/main.py", line 70, in render
#     component.render()
#   File "/content/SfM-with-LightGlue-Streamlit/Aspect/main.py", line 183, in render
#     img_slots = st.columns(n_slots)
# ...

# %%
# !curl https://loca.lt/mytunnelpassword
# Out:
# 34.170.112.125
